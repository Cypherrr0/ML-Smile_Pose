# %% [markdown]
# # CBU5201 mini-project Task 1

# %% [markdown]
# # Author
#
# **Student Name**: Yunzhong Zhang
# **Student ID**: QMID: 210982321 BUPTID: 2021213148

# %% [markdown]
# # 1 Smiling Dection

# %% [markdown]
# ## 1.1 Problem formulation
#
# I want to use machine learning to build models that can recognize smiles and head pose.

# %% [markdown]
# ## 1.2 Machine Learning pipeline

# %% [markdown]
# ### 1.2.1 Proprocessing stage
#
# The input to the machine learning pipeline is the raw images and their corresponding labels. The pipeline begins with the preprocessing stage, where images are loaded from a directory and labels are read from a text file. The images are then resized to a standard size and normalized to a range between 0 and 1. The labels are converted into a numerical array. The data is then split into training, validation, and test sets. The output of this stage, which also serves as the input to the next stage, is the preprocessed images and labels.

# %% [markdown]
# ### 1.2.2 Model Definition and Compilation stage
#
# The next stage is the definition and compilation of the model, where the input is the preprocessed data and the output is the compiled model. A Convolutional Neural Network (CNN) model is defined using Keras. This model includes three convolutional layers, each followed by a max pooling layer, a flatten layer to convert the 3D outputs to 1D, and then two dense layers. The model is compiled using the SGD optimizer, with binary cross-entropy as the loss function and accuracy as the evaluation metric. This compiled model will be used for the next stage of model training.

# %% [markdown]
# ### 1.2.3 Model Training stage
#
# The third stage is model training, where the input is the compiled model and the training data, and the output is the trained model. Here, data augmentation is applied to the training data to increase the diversity of the data and improve the model’s generalization ability. The model is trained using the augmented data, and the model is evaluated using the validation data after each epoch. The trained model will be used for the next stage of model evaluation.

# %% [markdown]
# ### 1.2.4 Model Evaluation and Visualization stage
#
# The final stage is model evaluation and visualization. The input is the trained model and the test data, and the output is the performance metrics (loss and accuracy) of the model on the test data, as well as the accuracy and loss curves of training and validation. The trained model is evaluated on the test data to obtain the test loss and accuracy. The accuracy and loss of training and validation are plotted against epochs to visualize the performance of the model during training.

# %% [markdown]
# ## 1.3 Transformation stage
#
# There are several transformation stages that serve as crucial steps in preparing the data for the machine learning model. The first transformation occurs in the preprocessing stage where raw images are loaded and resized to a standard size of 100x100 pixels. This is an important step because it ensures that all images have the same dimensions, which is a requirement for feeding them into the Convolutional Neural Network (CNN).
#
# The images are then normalized to a range between 0 and 1. Normalization is a common practice in machine learning as it ensures that all input features (in this case, pixel intensities) have the same scale, preventing any one feature from dominating others and allowing the model to learn more effectively.
#
# Another transformation is the conversion of labels into a numerical array. This is done because machine learning models work with numerical data and cannot process categorical data or text in their raw form.
#
# In the model training stage, data augmentation is applied to the training data. This involves making slight modifications to the original images, such as rotating or shifting them. This increases the diversity of the training data and helps improve the model’s ability to generalize, thereby enhancing its performance on unseen data.
#
# Finally, the output of the CNN is flattened before being fed into the dense layers. This is because while the convolutional and pooling layers work with 3D data, the dense layers require 1D input. Flattening thus serves as a bridge between these layers.

# %% [markdown]
# ## 1.4 Modelling
#
# Convolutional Neural Network (CNN) model is chosen because CNNs are great at picking up on patterns in the input image by applying filters and using pooling layers to reduce dimensionality, thereby capturing the essential features of the images.
#
# To determine whether people in the picture is smiling or not, it is certain to define it as a binary classification problem.
#
# This model consists of three sets of Conv2D and MaxPooling2D layers for feature extraction, followed by a Flatten layer and two Dense layers for classification. A Dropout layer is included to prevent overfitting. The final Dense layer uses a sigmoid activation function, indicating it is used for binary classification.

# %% [markdown]
# ## 1.5 Methodology
#
# The model will be trained using Stochastic Gradient Descent (SGD) as the optimizer, with a learning rate of 0.01 and momentum of 0.9. The model is compiled with the binary cross-entropy loss function, which is suitable for binary classification problems, and accuracy as the metric to evaluate the model’s performance.
#
# To augment the training data and make the model more robust, an ImageDataGenerator is used. This generator applies random transformations to the images, such as rotations, width and height shifts, and horizontal flips. These augmentations can help the model generalize better to unseen data by providing a broader representation of the possible variations in the training data.
#
# The model is then trained for 50 epochs using the augmented data. The batch size for training is set to 32. During each epoch, the model learns from the training data and its weights are updated to minimize the loss.
#
# The validation data, which is a separate dataset not used in training, is used to evaluate the model’s performance at the end of each epoch. This gives an indication of how well the model is likely to perform on unseen data. The training process is verbose, meaning it will output logs at each epoch to show the training and validation loss and accuracy.

# %% [markdown]
# The performance of the model is assessed using a combination of methods. First, the model’s loss and accuracy are evaluated on the test data, which provides a direct measure of how well the model performs on unseen data. The loss gives an indication of how well the model’s predictions align with the actual labels, while the accuracy provides the proportion of correct predictions.
#
# In addition to these direct measures, the training process is visualized to provide insights into the model’s learning over time. The accuracy and loss for both the training and validation data are plotted against the number of epochs. This allows us to observe how the model’s performance improves as it learns from the training data, and how well it generalizes to new data, as indicated by the validation accuracy and loss.
#
# These plots also help identify any potential issues, such as overfitting, where the model performs well on the training data but poorly on the validation data.

# %% [markdown]
# ## 1.6 Dataset
#
# The dataset consists of images and their corresponding labels. The images are loaded and preprocessed, and the data is split into training and test sets. The training set is further split into a training set and a validation set.
#
# The first step is image cropping. We use a pre-trained Haar cascade classifier for detecting faces in images. Then we traverse all the images in the specified folder and perform face detection on each image. If a face is detected in the image, the face part will be cropped out and its size will be adjusted to 200x200 pixels. If no face is detected, the original image will be directly resized to 200x200 pixels. Finally, all processed images will be saved to another specified folder. This process is repeated on the entire image set until all images have been processed.
#
# The train_test_split function in Scikit-learn is used to randomly partition a dataset into a training set and a test set, which are used for model training and evaluation, respectively.
#
# Function preprocess_data, normalizes image data to a range of 0-1 by converting the data type to float32 and dividing by 255.0 to ensure consistent data scale.

# %% [markdown]
# ## 1.7 Results

# %%
IMG_SIZE = 100
import cv2
import os
import numpy as np
import shutil
import tensorflow
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.optimizers import SGD
from tqdm import tqdm
# Preprocessing
# Load Haar cascade classifier
face_cascade = cv2.CascadeClassifier('D:\\CollegeStuff\\haarcascade_frontalface_default.xml')

# Read image path
path_read = "D:\\CollegeStuff\\大三上\\机器学习\\Mini Project\\Mini Project\\genki4k\\files"
num = 1
print("开始检测...")
for file_name in os.listdir(path_read):
    aa = (path_read + "/" + file_name)
    img = cv2.imdecode(np.fromfile(aa, dtype=np.uint8), cv2.IMREAD_UNCHANGED)

    # Perform face detection using the cascade classifier
    faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # The path to store the generated single face image.
    path_save = "D:\\CollegeStuff\\大三上\\机器学习\\Mini Project\\Mini Project\\files_choped"

    if len(faces) == 0:
        # If no face is detected, resize the original image to 200x200 pixels and then copy it to a new folder.
        img_resized = cv2.resize(img, (200, 200), interpolation=cv2.INTER_CUBIC)
        cv2.imencode('.jpg', img_resized)[1].tofile(path_save + "\\" + "file" + str(num) + ".jpg")
        print(f"No face detected, original image size adjusted and copied, serial number:{num}")
    else:
        for (x, y, w, h) in faces:
            # Generate an empty image based on the size of the face
            img_blank = img[y:y + h, x:x + w]
            img_blank = cv2.resize(img_blank, (200, 200), interpolation=cv2.INTER_CUBIC)

        cv2.imencode('.jpg', img_blank)[1].tofile(path_save + "\\" + "file" + str(num) + ".jpg")
    num += 1

print("New images generated")


# Load dataset
def load_img(img_dir):
    images = []
    # Read image
    for filename in os.listdir(img_dir):
        if filename.endswith('.jpg'):
            img = cv2.imread(os.path.join(img_dir, filename))
            if img is None:
                print(f"Image file {filename} not found.")
            else:
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                images.append(img)

    return np.array(images)

def load_labels(label_file):
    labels = []
    # Read label
    with open(label_file, 'r') as f:
        for line in f:
            labels.append(int(line.strip()[0]))
    labels = np.array(labels)
    return labels



# Data preprocessing
def preprocess_data(images):
    # Normalize the image data to the range 0-1.
    images = images.astype('float32') / 255.0
    return images

images = load_img('genki4k/files')
labels = load_labels('genki4k/labels.txt')
images = preprocess_data(images)
# Split training and testing sets.
train_data, test_data, train_labels, test_labels = train_test_split(images, labels, test_size=0.15, random_state=42)

# Split again into training and validation sets.
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.25, random_state=2)


from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(layers.Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.summary()

optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Use data augmentation.
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)
print("start training")
# Start training
history = model.fit(datagen.flow(train_data, train_labels, batch_size=32),
                    steps_per_epoch=len(train_data) / 32,
                    epochs=50,
                    validation_data=(val_data, val_labels),
                    verbose=1)


loss, accuracy = model.evaluate(test_data, test_labels)
print(f"Test loss: {loss}")
print(f"Test accuracy: {accuracy}")

# Visualize training result
plt.figure(figsize=(12,5))
# Plot accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict the values from the validation dataset
y_pred = model.predict(test_data)
# Convert predictions to binary classes
y_pred_classes = (y_pred > 0.5).astype(int).reshape(-1)
# Convert validation observations to one hot vectors
y_true = test_labels
# Compute the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes) 

# Plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 开始检测...
# No face detected, original image size adjusted and copied, serial number:16
# No face detected, original image size adjusted and copied, serial number:19
# No face detected, original image size adjusted and copied, serial number:65
# No face detected, original image size adjusted and copied, serial number:172
# No face detected, original image size adjusted and copied, serial number:183
# No face detected, original image size adjusted and copied, serial number:199
# No face detected, original image size adjusted and copied, serial number:209
# No face detected, original image size adjusted and copied, serial number:279
# No face detected, original image size adjusted and copied, serial number:291
# No face detected, original image size adjusted and copied, serial number:331
# No face detected, original image size adjusted and copied, serial number:335
# No face detected, original image size adjusted and copied, serial number:353
# ...

# %% [markdown]
# The test loss is 0.3550, which is the average error of the model on unseen test data. The lower the loss, the better the performance of the model. In this case, 0.3550 is a relatively low value, indicating that the model has a fairly high prediction accuracy when dealing with unseen data. The test accuracy is 0.8433, which means that the model has an accuracy rate of 84.33% on unseen data. This is a fairly high accuracy rate, indicating that the model performs very well on classification tasks.
#
# From the image, it can be seen that both the training accuracy and the validation accuracy increase with the increase of training epochs. This indicates that the model is effective in the learning process and there is no overfitting. At the same time, both the training loss and the validation loss decrease with the increase of training epochs. This is a good sign, indicating that the model is effective in the learning process and there is no overfitting.

# %% [markdown]
# ## 1.8 Conclusions
#
# The code covers the complete machine learning process from data preprocessing to model training and validation, which is very comprehensive and systematic. After evaluation, the model performs well, indicating that my preprocessing and the choice of CNN as the model are correct.
#
# An area for improvement is that the recognition rate of the Haar cascade classifier for faces is not ideal and there are certain errors. Other methods can be used for image cropping.

# %% [markdown]
# # 2 3D Head Pose Estimation

# %% [markdown]
# ## 2.1 Problem formulation
#
# Our machine learning problem is to predict the 3D pose features of the head in images using the genki4k dataset. What’s interesting about this problem is that we not only have to deal with image data, but also extract features. This is a regression problem, not the common classification problem.

# %% [markdown]
# ## 2.2 Machine Learning pipeline
#
# ### 2.2.1 Data Loading and Preprocessing Stage
#
# First, we load the images, crop them, adjust their size, and convert them to RGB format. This is necessary because our model requires a fixed size input, and RGB format images can provide more information. Then, we load the label file, which contains the target values for each image. These values are what our model needs to predict. The input of this stage is the original dataset, and the output is an array containing preprocessed images and an array containing all labels.
#
# ### 2.2.2 Feature Extraction Stage
#
# We perform feature extraction on the images, convert the images to grayscale, and then use HOG descriptors to extract features. The input of this stage is the array of preprocessed images, and the output is an array containing all image features.
#
# ### 2.2.3 Data Partitioning Stage
#
# We use the train_test_split function to divide the labels and features into training sets, validation sets, and test sets. This is necessary because we need an independent dataset to evaluate our model’s performance. The input of this stage is the feature array and label array, and the output is the training set, validation set, and test set, each with labels and corresponding feature values.
#
# ### 2.2.4 Model Building and Training and Validation
#
# We use the random forest regression model for training and use mean squared error (MSE) and mean absolute error (MAE) to evaluate model performance. In this stage, we first use the training set to train the model, and then use the validation set to evaluate the model’s performance. The input of this stage is the training set and validation set, and the output is the trained model, as well as the performance indicators of the model on the training set and validation set.
#
# ### 2.2.5 Model Testing and Visualization
#
# Finally, we use the test set to evaluate the final performance of our model, randomly display a set of data’s actual values and predicted values, and visualize the performance indicators. The output of this stage is the performance indicators of the model on the test set.

# %% [markdown]
# ## 2.3 Transformation stage

# %% [markdown]
# In the transformation stage, we carried out two main steps: image preprocessing and feature extraction.
#
# Image Preprocessing: In this step, we used the cv2.imread function to read the image, then used the cv2.resize function to adjust the size of the image to the size required by the model. Next, we used the cv2.cvtColor function to convert the image from BGR format to RGB format. This is because the cv2.imread function reads images in BGR format by default, but our model requires images in RGB format. The input of this step is the original BGR image, and the output is the preprocessed RGB image.
#
# Feature Extraction: In this step, we first used the cv2.cvtColor function to convert the RGB image to grayscale, then used the cv2.resize function to reduce the size of the image, which can reduce computational complexity and improve the training speed of the model. Then, we created a HOG descriptor object and used the hog.compute function to extract the HOG features of the image to capture the shape information of the image. The input of this step is the preprocessed RGB image, and the output is the HOG features of the image.

# %% [markdown]
# ## 2.4 Modelling

# %% [markdown]
# In the modeling stage, we chose the random forest regression model. Random forest is an ensemble learning method that makes predictions by integrating multiple decision tree models. In our code, we used the sklearn.ensemble.RandomForestRegressor class to create a random forest model.
#
# We created a RandomForestRegressor object and set some parameters, such as n_estimators and max_depth. The n_estimators parameter indicates the number of decision trees we want to use in the random forest, and the max_depth parameter indicates the maximum depth of each decision tree.
#
# We chose the random forest model because it has several advantages. First, random forests can handle high-dimensional data, which is very important for our task because image features are usually high-dimensional. Second, random forests are not sensitive to outliers, which means that even if there is some noise in our data, it can provide stable prediction results. Finally, random forests can provide feature importance, which can help us understand which features are most important for prediction.

# %% [markdown]
# ## 2.5 Methodology

# %% [markdown]
# In terms of methodology, we adopted the following steps to train and validate the model, as well as evaluate the model’s performance:
#
# Model Training: We used the fit method of the random forest regression model for model training. This method accepts two parameters: a feature array and a target array. The feature array contains the features we extracted from the images, and the target array contains the target values for each image. During the training process, the model tries to find the relationship between the features and the targets so that it can accurately predict the target values when given new features.
#
# Model Validation: We used an independent validation set to evaluate the model’s performance. The validation set is partitioned from the original dataset and does not participate in model training. We used the model’s predict method to make predictions on the validation set, and then compared the predicted results with the actual values to evaluate the model’s performance.
#
# Performance Evaluation: We used Mean Squared Error (MSE) and Mean Absolute Error (MAE) to evaluate the model’s performance. MSE is the average of the squares of the differences between the predicted values and the actual values, which measures the size of the squared prediction errors. MAE is the average of the absolute values of the differences between the predicted values and the actual values, which measures the size of the prediction errors. Both of these metrics can quantify the gap between the model’s predictions and the actual values.

# %% [markdown]
# ## 2.6 Dataset
#
# Our dataset contains a series of images and corresponding labels. The images are stored in a directory, each with a corresponding label stored in a text file. Each line in the label file corresponds to an image and contains the target value for that image.
#
# In the preprocessing stage, we performed a series of operations on the images. First, we used the cv2.imread function to read the images. Then, we used the cv2.resize function to adjust the size of the images to the size required by the model. Next, we used the cv2.cvtColor function to convert the images from BGR format to RGB format. This is because the cv2.imread function reads images in BGR format by default, but our model requires images in RGB format. Finally, we normalized the pixel values of the images to the range 0-1, which can help the model better learn the features of the images.
#
# In the feature extraction stage, we first used the cv2.cvtColor function to convert the RGB images to grayscale. Then, we used the cv2.resize function to reduce the size of the images. Next, we created a HOG descriptor object and used the hog.compute function to extract the HOG features of the images.

# %% [markdown]
# ## 2.7 Result

# %%
IMG_SIZE = 100
import cv2
import dlib
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from math import radians
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
# Preprocessing
# Load Haar cascade classifier
face_cascade = cv2.CascadeClassifier('D:\\CollegeStuff\\haarcascade_frontalface_default.xml')
# 加载dlib的人脸检测器和人脸关键点检测器
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('D:\\CollegeStuff\\shape_predictor_68_face_landmarks.dat')
# Read image path
path_read = "D:\\CollegeStuff\\大三上\\机器学习\\Mini Project\\Mini Project\\genki4k\\files"

num = 1
print("开始检测...")
for file_name in os.listdir(path_read):
    aa = (path_read + "/" + file_name)

    img = cv2.imdecode(np.fromfile(aa, dtype=np.uint8), cv2.IMREAD_UNCHANGED)

    # Perform face detection using the cascade classifier
    faces = face_cascade.detectMultiScale(img, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    # The path to store the generated single face image.
    path_save = "D:\\CollegeStuff\\大三上\\机器学习\\Mini Project\\Mini Project\\files_choped"

    if len(faces) == 0:
        # If no face is detected, resize the original image to 200x200 pixels and then copy it to a new folder.
        img_resized = cv2.resize(img, (200, 200), interpolation=cv2.INTER_CUBIC)
        cv2.imencode('.jpg', img_resized)[1].tofile(path_save + "\\" + "file" + str(num) + ".jpg")
        print(f"No face detected, original image size adjusted and copied, serial number:{num}")
    else:
        for (x, y, w, h) in faces:
            # Generate an empty image based on the size of the face
            img_blank = img[y:y + h, x:x + w]
            img_blank = cv2.resize(img_blank, (200, 200), interpolation=cv2.INTER_CUBIC)
        cv2.imencode('.jpg', img_blank)[1].tofile(path_save + "\\" + "file" + str(num) + ".jpg")
    num += 1
print("New images generated")

def load_img(img_dir):
    images = []
    # Read image
    for filename in os.listdir(img_dir):
        if filename.endswith('.jpg'):
            img = cv2.imread(os.path.join(img_dir, filename))
            if img is None:
                print(f"Image file {filename} not found.")
            else:
                # Resize image
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                # Convert image to RGB
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                images.append(img)
    
    return np.array(images)

# Read label
def load_labels(label_file):
    label_data = []
    with open(label_file, 'r') as file:
        for line in file.readlines():
            data = line.split()
            yaw, pitch, roll = map(float, map(float, data[1:]))
            label_data.append([yaw, pitch, roll])
    return np.array(label_data)

# Data preprocessing
def preprocess_data(images):
    # Normalize the image data to the range 0-1.
    images = images.astype('float32') / 255.0
    return images

import cv2
import numpy as np

def extract_features(image):
    # 将图像转换为灰度图像
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # 将图像的数据类型转换为np.uint8
    gray = gray.astype(np.uint8)
    
    # 将图像尺寸缩小
    gray = cv2.resize(gray, (128, 128))
    
    # 创建HOG对象
    hog = cv2.HOGDescriptor()
    
    # 使用HOG对象提取特征
    features = hog.compute(gray)
    
    # 将特征展平
    features = features.flatten()
    
    return features


images = load_img('files_choped')#files_choped
labels = load_labels('genki4k/labels.txt')
images = preprocess_data(images)
print("Start extracting")
features = [extract_features(image) for image in images]
print("Extract finished")
# Remove rows with None values
features = [f for f in features if f is not None]

features = np.array(features)



print("Start spliting")
# Split training and testing sets.
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.15, random_state=42)
# Split again into training and validation sets.
train_features, val_features, train_labels, val_labels = train_test_split(train_features, train_labels, test_size=0.25, random_state=2)
print("Spliting finished")
train_errors = []
val_errors = []
# 创建列表以收集训练损失和验证损失
train_losses = []
val_losses = []
# 构建模型
model = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
# 在每一轮迭代中，我们将训练模型，并收集训练误差和验证误差
print("Starting training")
for i in tqdm(range(1, 11)):
    model.set_params(n_estimators=i)
    model.fit(train_features, train_labels)
    train_predictions = model.predict(train_features)
    val_predictions = model.predict(val_features)
    train_errors.append(mean_absolute_error(train_labels, train_predictions))
    val_errors.append(mean_absolute_error(val_labels, val_predictions))
    train_error = mean_absolute_error(train_labels, train_predictions)
    val_error = mean_absolute_error(val_labels, val_predictions)
    train_losses.append(train_error)
    val_losses.append(val_error)
    # 打印训练误差和验证误差
    print("Training MSE: ", train_errors[-1])
    print("Validation MSE: ", val_errors[-1])

# 在所有轮次结束后，使用最优模型在测试集上进行预测
test_predictions = model.predict(test_features)
# 计算测试集的MSE和MAE
test_mse = mean_squared_error(test_labels, test_predictions)
test_mae = mean_absolute_error(test_labels, test_predictions)
# 输出测试集的MSE和MAE
print("Test MSE: ", test_mse)
print("Test MAE: ", test_mae)

# 选择一个测试样本
sample_index = np.random.randint(len(test_labels))  # 随机选择一个测试样本
sample_features = test_features[sample_index]  # 获取该样本的特征
sample_label = test_labels[sample_index]  # 获取该样本的真实标签

# 使用模型进行预测
sample_features_reshaped = sample_features.reshape(1, -1)  # 重塑特征以匹配模型的输入形状
sample_prediction = model.predict(sample_features_reshaped)  # 使用模型进行预测

# 打印真实标签和预测标签
print("True label: ", sample_label)
print("Predicted label: ", sample_prediction)

# 绘制训练误差和验证误差
plt.figure()
plt.plot(train_errors, label='Training error')
plt.plot(val_errors, label='Validation error')
plt.legend()
plt.title('Training and validation error')
plt.xlabel('Number of trees')
plt.ylabel('Mean Absolute Error')
plt.show()

# 绘制训练误差和验证误差
plt.figure()
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.xlabel('Number of trees')
plt.ylabel('Mean Absolute Error')
plt.show()
# Out:
# 开始检测...
# No face detected, original image size adjusted and copied, serial number:16
# No face detected, original image size adjusted and copied, serial number:19
# No face detected, original image size adjusted and copied, serial number:65
# No face detected, original image size adjusted and copied, serial number:172
# No face detected, original image size adjusted and copied, serial number:183
# No face detected, original image size adjusted and copied, serial number:199
# No face detected, original image size adjusted and copied, serial number:209
# No face detected, original image size adjusted and copied, serial number:279
# No face detected, original image size adjusted and copied, serial number:291
# No face detected, original image size adjusted and copied, serial number:331
# No face detected, original image size adjusted and copied, serial number:335
# No face detected, original image size adjusted and copied, serial number:353
# ...

# %% [markdown]
# The visualization of Error and Loss shows that the error rate is decreasing in both the training set and the validation set, indicating that the model is successfully learning during this process. The MSE and MAE of the model on the test set are relatively small, indicating that the model has good predictive performance. However, there is still some gap between the true labels and the predicted labels, which means that there is room for improvement in the model.

# %% [markdown]
# ## 2.8 Conclusions
#
# Although the model seems to perform well in terms of parameters, I am personally not satisfied with the performance of this model, which can be seen from the gap between the predicted values and the actual values. One of the reasons I think is that the HOG’s ability to extract image features is not good enough, which leads to the random forest model not being able to learn fully. Next, I will try to use different image feature extraction and preprocessing methods to see if I can optimize the performance of the model.
